# %% [markdown]
# # 1. 사칙연산

# %%
1+1
2+2
# Out:
# 4

# %% [markdown]
# # 2. 변수대입과 계산

# %%
Print("hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9e94fdc0344b> in <module>
# ----> 1 Print("hello world")
#
# NameError: name 'Print' is not defined

# %%
print("hello world")
# Out:
# hello world

# %%
a="hello world"
print(a)
# Out:
# hello world

# %%
#  4.조건문

# %%
a=2

# %%
a=2
if a >1 :
# Out:
#   File "<ipython-input-8-5d48b246fc73>", line 2
#     if a >1 :
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
a=2
if a>1 :
  print("a is greater than 1")
# Out:
# a is greater than 1

# %%
for a in[1,2,3] :
  print(a)
# Out:
# 1
# 2
# 3

# %%
a_list = [70,60,55,75,95,90,80,80,85,100]

for score in a_list:
  total = sum(a_list)
average = total/len(a_list)
print(average)
# Out:
# 79.0

# %% [markdown]
# 주어진 자연수가 홀수인지 짝수인지 판별해주는 함수(is_odd)를 작성해 보자

# %%
def is_odd(i) :

  if i % 2 ==0 :
    return print("짝수")
  else :
    print("홀수")

# %%
is_odd(3)
# Out:
# 홀수
